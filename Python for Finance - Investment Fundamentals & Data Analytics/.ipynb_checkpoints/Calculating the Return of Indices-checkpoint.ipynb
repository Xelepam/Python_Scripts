# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
#S&P500: ^GSPC
#NASDAQ: ^IXIC
#German DAX: ^GDAXI
#London FTSE: ^FTSE

tickers = ['^GSPC','^IXIC','^GDAXI','^FTSE']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  4057.399902
# 1997-01-03  748.030029  1310.680054  2863.260010  4089.500000
# 1997-01-06  747.650024  1316.400024  2890.199951  4106.500000
# 1997-01-07  753.229980  1327.729980  2876.340088  4078.800049
# 1997-01-08  748.409973  1320.349976  2904.080078  4087.500000

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI        ^FTSE
# Date
# 2017-10-16  2557.639893  6624.000000  13003.700195  7527.000000
# 2017-10-17  2559.360107  6623.660156  12995.059570  7516.200195
# 2017-10-18  2561.260010  6624.220215  13043.030273  7542.899902
# 2017-10-19  2562.100098  6605.069824  12990.099609  7523.000000
# 2017-10-20  2575.209961  6629.049805  12991.280273  7523.200195

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize = (15, 6))
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2017-10-16  0.001751  0.002755  0.000911 -0.001115
# 2017-10-17  0.000673 -0.000051 -0.000664 -0.001435
# 2017-10-18  0.000742  0.000085  0.003691  0.003552
# 2017-10-19  0.000328 -0.002891 -0.004058 -0.002638
# 2017-10-20  0.005117  0.003631  0.000091  0.000027

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.078200
# ^IXIC     0.110417
# ^GDAXI    0.087119
# ^FTSE     0.044066
# dtype: float64

# %%
tickers = ['NVDA','^IXIC','^DJI']

data2 = pd.DataFrame()

for t in tickers:
    data2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2016-1-1')['Adj Close']

# %%
data2.tail()
# Out:
#                   NVDA        ^IXIC          ^DJI
# Date
# 2017-10-16  197.929993  6624.000000  22956.960938
# 2017-10-17  197.750000  6623.660156  22997.439453
# 2017-10-18  197.580002  6624.220215  23157.599609
# 2017-10-19  197.800003  6605.069824  23163.039063
# 2017-10-20  196.899994  6629.049805  23328.630859

# %%
(data2 / data2.iloc[0] * 100).plot(figsize = (15,6))
plt.show()
